# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content
# !git clone https://github.com/ultralytics/yolov5
# Out:
# /content
# Cloning into 'yolov5'...
# remote: Enumerating objects: 14379, done.
# remote: Counting objects: 100% (185/185), done.
# remote: Compressing objects: 100% (116/116), done.
# remote: Total 14379 (delta 116), reused 125 (delta 69), pack-reused 14194
# Receiving objects: 100% (14379/14379), 13.43 MiB | 24.04 MiB/s, done.
# Resolving deltas: 100% (9926/9926), done.

# %%
# %cd /content/yolov5/
# !pip install -r requirements.txt

# %%
# %cat /content/drive/MyDrive/dmdkr_guitar/neck_dataset/data.yaml
# Out:
# train: /content/drive/MyDrive/dmdkr_guitar/neck_dataset/train.txt
# val: /content/drive/MyDrive/dmdkr_guitar/neck_dataset/val.txt
#
# nc: 1
# names: ['neck']

# %%
# %cd /
from glob import glob

img_list = glob('/content/drive/MyDrive/dmdkr_guitar/neck_dataset/images/*.jpg')
img_list = img_list+glob('/content/drive/MyDrive/dmdkr_guitar/neck_dataset/images/*.jpeg')

print(len(img_list))
# Out:
# /
# 139

# %%
from sklearn.model_selection import train_test_split

train_img_list, val_img_list = train_test_split(img_list, test_size=0.25, random_state=42)

print(len(train_img_list), len(val_img_list))
# Out:
# 104 35

# %%
with open('/content/drive/MyDrive/dmdkr_guitar/neck_dataset/train.txt' , 'w') as f:
  f.write('\n'.join(train_img_list) + '\n')

with open('/content/drive/MyDrive/dmdkr_guitar/neck_dataset/val.txt', 'w') as f:
  f.write('\n'.join(val_img_list) + '\n')

# %%
# !python /content/yolov5/train.py --batch 8 --epochs 200 --data /content/drive/MyDrive/dmdkr_guitar/neck_dataset/data.yaml --weights yolov5m.pt --name result_neck_weight --cfg /content/yolov5/models/yolov5m.yaml
# Out:
# train: weights=yolov5m.pt, cfg=/content/yolov5/models/yolov5m.yaml, data=/content/drive/MyDrive/dmdkr_guitar/neck_dataset/data.yaml, hyp=content/yolov5/data/hyps/hyp.scratch-low.yaml, epochs=200, batch_size=8, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=content/yolov5/runs/train, name=result_neck_weight, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.2-205-geef9057 Python-3.7.15 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# ...
